# %%
import pandas as pd
import folium

# %%
df_sw = pd.read_csv('tundra_swan.csv', parse_dates=['TimeStamp'])

# %%
df_co2 = pd.read_csv('co2.csv', parse_dates=['start_date','end_date'])

# %%
df_sw = df_sw.set_index('TimeStamp')

# %%
df_co2 = df_co2.set_index('start_date')

# %%
df_sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90378 entries, 2008-07-21 12:52:14+00:00 to 2012-07-31 15:56:36+00:00
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           90378 non-null  object
#  1   description  90378 non-null  object
#  2   longitude    90378 non-null  float64
#  3   latitude     90378 non-null  float64
#  4   range        90378 non-null  float64
#  5   tilt         90378 non-null  float64
#  6   heading      90378 non-null  float64
#  7   coordinates  90378 non-null  object
#  8   color        90378 non-null  object
# dtypes: float64(5), object(4)
# memory usage: 6.9+ MB

# %%
odate = '2010-05'

# %%
m = folium.Map([50, -120], zoom_start=3)

# %%
for index, row in df_sw[odate].iterrows():
  folium.CircleMarker([row['latitude'], row['longitude']],
                      popup=row['description'], 
                      radius=10, 
                      fill=True,
                      color=row['color'], 
                      fill_color=row['color'],
                      fill_opacity=0.5,
                      opacity=0.5).add_to(m)
# Out:
# C:\Users\victor\AppData\Local\Temp\ipykernel_26284\4191017847.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df_sw[odate].iterrows():

# %%
for index, row in df_co2[odate].iterrows():
    folium.Marker([row['latitude'],row['longitude']], popup=f"Temp:{row['tair_int']}\nNee:{row['nee']}").add_to(m)
# Out:
# C:\Users\victor\AppData\Local\Temp\ipykernel_26284\1761531700.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df_co2[odate].iterrows():

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64b4e318d1a1aa6c433e3ee93c01370b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64b4e318d1a1aa6c433e3ee93c01370b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_64b4e318d1a1aa6c433e3ee93c01370b = L.map(
#                 &quot;map_64b4e318d1a1aa6c433e3ee93c01370b&quot;,
#                 {
#                     center: [50.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb2e2e23094bd438a582d82e941ecc87 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_64b4e318d1a1aa6c433e3ee93c01370b);
#
#
#             var circle_marker_3277369fc8cab07095e8f6d10363cdee = L.circleMarker(
#                 [55.294, -162.744],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7CD41F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7CD41F&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_64b4e318d1a1aa6c433e3ee93c01370b);
#
#
#         var popup_829e5e7fa1c6b6f28e7f0ceae60777f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9960e9b3568916b79eccdf6998deebd8 = $(`&lt;div id=&quot;html_9960e9b3568916b79eccdf6998deebd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal: TUSW_CB1  PTT: 80510  DateTime: 5/2/10:17:47:3 Location Class: LB  Dist From Previous Loc:      0.83 km Rate From Previous Loc:       0.0 km/hr Azimuth From Previous Loc: 123 Hours Since Previous Loc:      82.14 Days Since Previous Loc:     3.42&lt;/div&gt;`)[0];
#             popup_829e5e7fa1c6b6f28e7f0ceae60777f2.setContent(html_9960e9b3568916b79eccdf6998deebd8);
#
#
#         circle_marker_3277369fc8cab07095e8f6d10363cdee.bindPopup(popup_829e5e7fa1c6b6f28e7f0ceae60777f2)
#         ;
#
#
#
#
#             var circle_marker_0fab8aa8bb6cd330cd9e6796e8704575 = L.circleMarker(
#                 [55.3, -162.756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7CD41F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7CD41F&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_64b4e318d1a1aa6c433e3ee93c01370b);
#
#
#         var popup_a62fe743e8970e27fbec6a73241cba8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b470dafd1758d4a50ece2d6f47de1309 = $(`&lt;div id=&quot;html_b470dafd1758d4a50ece2d6f47de1309&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal: TUSW_CB1  PTT: 80510  DateTime: 5/2/10:18:35:33 Location Class: LB  Dist From Previous Loc:      1.01 km Rate From Previous Loc:       1.3 km/hr Azimuth From Previous Loc: 311 Hours Since Previous Loc:       0.81 Days Since Previous Loc:     0.03&lt;/div&gt;`)[0];
#             popup_a62fe743e8970e27fbec6a73241cba8e.setContent(html_b470dafd1758d4a50ece2d6f47de1309);
#
#
#         circle_marker_0fab8aa8bb6cd330cd9e6796e8704575.bindPopup(popup_a62fe743e8970e27fbec6a73241cba8e)
#         ;
#
#
#
#
#             var circle_marker_f2efb950c9fa03b596e8dab1ae3914c6 = L.circleMarker(
#                 [55.295, -162.743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7CD41F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7CD41F&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_64b4e318d1a1aa6c433e3ee93c01370b);
#
#
#         var popup_834242f5de8f630ce1579fa64d1e99b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cfbcf4e29dd1100d79e2882ccc29feea = $(`&lt;div id=&quot;html_cfbcf4e29dd1100d79e2882ccc29feea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal: TUSW_CB1  PTT: 80510  DateTime: 5/2/10:18:36:34 Location Class: L2  Dist From Previous Loc:      1.00 km Rate From Previous Loc:      57.8 km/hr Azimuth From Previous Loc: 124 Hours Since Previous Loc:       0.02 Days Since Previous Loc:     0.00&lt;/div&gt;`)[0];
#             popup_834242f5de8f630ce1579fa64d1e99b2.setContent(htm

# %%
import gradio as gr

# %%
def map(odate):
    m = folium.Map([50, -120], zoom_start=3)
    for index, row in df_sw[odate].iterrows():
      folium.CircleMarker([row['latitude'], row['longitude']],
                          popup=row['description'], 
                          radius=10, 
                          fill=True,
                          color=row['color'], 
                          fill_color=row['color'],
                          fill_opacity=0.5,
                          opacity=0.5).add_to(m)
    for index, row in df_co2[odate].iterrows():
        folium.Marker([row['latitude'],row['longitude']], popup=f"Temp:{row['tair_int']}\nNee:{row['nee']}").add_to(m)
    # html = m.get_root().render()
    html = m._repr_html_()
    html = (
        ""
        + html
        + ""
    )
    return html

# %%
months = []
for i in range(2008, 2013):
    for j in range(1, 13):
        if i==2008:
            if j < 7:
                continue
        elif i==2012:
            if j > 7:
                break
        months.append(f"{i}-{j:02}")

# %%
with gr.Blocks() as app:
    gr.Markdown("# Overseer")
    gr.Markdown("### Overseeing Bird Migration")
    gr.Markdown("Choose Year-Month from dropdown list, and wait for the result to show on the map!")
    dropdown = gr.Dropdown(months, label="Choose Year-Month")
    html = gr.HTML()
    dropdown.change(map, dropdown, html)

app.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7875/
# Running on public URL: https://23797.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://23797.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x23ee6cf9880>,
#  'http://127.0.0.1:7875/',
#  'https://23797.gradio.app')
# C:\Users\victor\AppData\Local\Temp\ipykernel_26284\486558524.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df_sw[odate].iterrows():
# C:\Users\victor\AppData\Local\Temp\ipykernel_26284\486558524.py:12: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df_co2[odate].iterrows():

# %%
gr.Interface(map, gr.Dropdown(months), "html", allow_flagging=False, live=True).launch()
# Out:
# C:\Users\victor\anaconda3\lib\site-packages\gradio\interface.py:355: UserWarning: The `allow_flagging` parameter in `Interface` nowtakes a string value ('auto', 'manual', or 'never'), not a boolean. Setting parameter to: 'never'.
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7865/
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x23ee76f1760>, 'http://127.0.0.1:7865/', None)
# C:\Users\victor\AppData\Local\Temp\ipykernel_26284\486558524.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df_sw[odate].iterrows():
# C:\Users\victor\AppData\Local\Temp\ipykernel_26284\486558524.py:12: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df_co2[odate].iterrows():
# Traceback (most recent call last):
#   File "C:\Users\victor\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3621, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 136, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 163, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5198, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5206, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\victor\anaconda3\lib\site-packages\gradio\routes.py", line 259, in run_predict
#     output = await app.blocks.process_api(
#   File "C:\Users\victor\anaconda3\lib\site-packages\gradio\blocks.py", line 687, in process_api
#     predictions, duration = await self.call_function(fn_index, inputs)
#   File "C:\Users\victor\anaconda3\lib\site-packages\gradio\blocks.py", line 604, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\victor\anaconda3\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#   File "C:\Users\victor\anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\victor\anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#   File "C:\Users\victor\AppData\Local\Temp\ipykernel_26284\486558524.py", line 3, in map
#     for index, row in df_sw[odate].iterrows():
#   File "C:\Users\victor\anaconda3\lib\site-packages\pandas\core\frame.py", line 3505, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\victor\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3623, in get_loc
#     raise KeyError(key) from err
# KeyError: None

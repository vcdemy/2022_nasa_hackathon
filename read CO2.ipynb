# %%
import pandas as pd
import folium

# %%
df = pd.read_csv("nasa/Arctic_Boreal_CO2_Flux.csv", encoding='cp1252')

# %%
df.head()
# Out:
#      id                study_id          study_id_short  \
# 0  1936  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 1  1937  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 2  1938  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 3  1939  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 4  1940  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
#
#                                            site_name site_reference country  \
# 0  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 1  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 2  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 3  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 4  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
#
#    latitude  longitude  start_date    end_date  ...  \
# 0   55.5375  -112.3343  2004-05-01  2004-05-31  ...
# 1   55.5375  -112.3343  2004-06-01  2004-06-30  ...
# ...

# %%
len(df)
# Out:
# 6309

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6309 entries, 0 to 6308
# Data columns (total 94 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             6309 non-null   int64
#  1   study_id                       6309 non-null   object
#  2   study_id_short                 6309 non-null   object
#  3   site_name                      6309 non-null   object
#  4   site_reference                 5963 non-null   object
#  5   country                        6309 non-null   object
#  6   latitude                       6309 non-null   float64
#  7   longitude                      6309 non-null   float64
#  8   start_date                     6309 non-null   object
#  9   end_date                       6309 non-null   object
#  10  meas_year                      6309 non-null   int64
#  11  season                         6309 non-null   object
# ...

# %%
df['start_date'] = pd.to_datetime(df['start_date'])

# %%
df['end_date'] = pd.to_datetime(df['end_date'])

# %%
df.head()
# Out:
#      id                study_id          study_id_short  \
# 0  1936  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 1  1937  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 2  1938  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 3  1939  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
# 4  1940  Adkinson_CA-WP2_tower1  Adkinson_CA-WP2_tower1
#
#                                            site_name site_reference country  \
# 0  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 1  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 2  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 3  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
# 4  Alberta - Western Peatland - Poor Fen (Sphagnu...         CA-WP2  Canada
#
#    latitude  longitude start_date   end_date  ...  \
# 0   55.5375  -112.3343 2004-05-01 2004-05-31  ...
# 1   55.5375  -112.3343 2004-06-01 2004-06-30  ...
# ...

# %%
df = df.set_index('start_date')

# %%
m = folium.Map([50, -120], zoom_start=6)

# %%
for index, row in df['2014-05'].iterrows():
    # icon = folium.DivIcon(html=f"{row['tair_int']}")
    # folium.Marker([row['latitude'],row['longitude']], icon=icon).add_to(m)
    folium.Marker([row['latitude'],row['longitude']], popup=f"Temp:{row['tair_int']}\nNee:{row['nee']}").add_to(m)
# Out:
# C:\Users\victor\AppData\Local\Temp\ipykernel_17504\399945696.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   for index, row in df['2014-05'].iterrows():

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df.to_csv('co2.csv')
